# %%
import streamlit as st
import pandas as pd

# %%
template = pd.read_csv("/Users/ethan/Desktop/UW Football/VERTICAL JUMP (JUMP MAT).csv")

# %%
template
# Out:
#      J#             Player   Pos  Vertical Jump (Jump Mat)  \
# 0    28      ADAMS II, SAM    RB                       NaN
# 1    67    ANDERSON, AIDAN    OL                       NaN
# 2     0    AZZOPARDI, DREW    OL                       NaN
# 3    55      BANDES, JACOB    DL                       NaN
# 4    19    BARKINS, DARREN    CB                       NaN
# ..   ..                ...   ...                       ...
# 104   0      WAYNE, JAYDEN  EDGE                       NaN
# 105   0   WILLIAMS, DEMOND    QB                       NaN
# 106   0  WILLIAMS, JUSTICE    WR                       NaN
# 107   3   WILLIAMS, RASHID    WR                       NaN
# 108   0      WRIGHT, RAHIM     S                       NaN
#
#      Vertical Jump (Jump Mat) Video Upload  Did not test?  \
# 0                                      NaN            NaN
# 1                                      NaN            NaN
# 2                                      NaN            NaN
# 3                                      NaN            NaN
# 4                                      NaN            NaN
# ..                                     ...            ...
# 104                                    NaN            NaN
# 105                                    NaN            NaN
# 106                                    NaN            NaN
# 107                                    NaN            NaN
# 108                                    NaN            NaN
#
#      Reason for not testing
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 104                     NaN
# 105                     NaN
# 106                     NaN
# 107                     NaN
# 108                     NaN
#
# [109 rows x 7 columns]

# %%
#Run the website

st.write("Hello")
# Out:
# 2024-06-22 09:02:55.756
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/ethan/Desktop/UW Football/.venv/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
